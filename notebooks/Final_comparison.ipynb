# %%
import pandas as pd
import mlflow
import dagshub
from sklearn.model_selection import cross_val_score, KFold, cross_validate
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.preprocessing import TargetEncoder
from feature_engine.encoding import CountFrequencyEncoder, MeanEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder
import optuna

# %%
# importing data 

train = pd.read_parquet('C:/Users/aksha/OneDrive/Desktop/AutoNexusMlOps/data/Exp/train.parquet')
validation = pd.read_parquet('C:/Users/aksha/OneDrive/Desktop/AutoNexusMlOps/data/Exp/validation.parquet')

# %%
df = pd.concat([train,validation])

xtrain = df.drop(columns='Price')
ytrain = df['Price'].copy()

# %%
def objective(trial):
    """
    Creating an objective function for HP in Optuna
    """
    # --- choose encoder ---
    encoder_type = trial.suggest_categorical(
        "encoder_type", ["Freq", "Count", "Target"]
    )

    # --- choose algorithm ---
    model_type = trial.suggest_categorical(
        "model", ["RandomForest", "XGBoost", "DecisionTree"]
    )

    # --- define transformer dynamically ---
    if encoder_type == "Freq":
        transformer = ColumnTransformer([
            ('ordinal_encoding',
             OrdinalEncoder(categories=[['New', 'Certified', 'Used']]),
             ['Stock_Type']),
            ('frequency',
             CountFrequencyEncoder(encoding_method='frequency'),
             ['Brand_Name', 'Model_Name', 'Exterior_Color',
              'Interior_Color', 'Drivetrain', 'Fuel_Type',
              'Cylinder_Config', 'City', 'STATE'])
        ], remainder='passthrough')

    elif encoder_type == "Count":
        transformer = ColumnTransformer([
            ('ordinal_encoding',
             OrdinalEncoder(categories=[['New', 'Certified', 'Used']]),
             ['Stock_Type']),
            ('count',
             CountFrequencyEncoder(encoding_method='count'),
             ['Brand_Name', 'Model_Name', 'Exterior_Color',
              'Interior_Color', 'Drivetrain', 'Fuel_Type',
              'Cylinder_Config', 'City', 'STATE'])
        ], remainder='passthrough')

    else:
        transformer = ColumnTransformer([
            ('ordinal_encoding',
             OrdinalEncoder(categories=[['New', 'Certified', 'Used']]),
             ['Stock_Type']),
            ('target',
             TargetEncoder(),
             ['Brand_Name', 'Model_Name', 'Exterior_Color',
              'Interior_Color', 'Drivetrain', 'Fuel_Type',
              'Cylinder_Config', 'City', 'STATE'])
        ], remainder='passthrough')

    # --- model selection and hyperparameters ---
    if model_type == "RandomForest":
        model = RandomForestRegressor(
            n_estimators=trial.suggest_int("rf_n_estimators", 100, 800, step=50),
            max_depth=trial.suggest_int("rf_max_depth", 5, 50),
            min_samples_split=trial.suggest_int("rf_min_samples_split", 2, 10),
            min_samples_leaf=trial.suggest_int("rf_min_samples_leaf", 1, 5),
            max_features=trial.suggest_categorical("rf_max_features", ["sqrt", "log2", None]),
            bootstrap=trial.suggest_categorical("rf_bootstrap", [True, False]),
            n_jobs=-1,
            random_state=42
        )

    elif model_type == "XGBoost":
        model = XGBRegressor(
            n_estimators=trial.suggest_int("xgb_n_estimators", 100, 1000, step=50),
            learning_rate=trial.suggest_float("xgb_learning_rate", 0.005, 0.3, log=True),
            max_depth=trial.suggest_int("xgb_max_depth", 3, 15),
            min_child_weight=trial.suggest_float("xgb_min_child_weight", 1.0, 10.0),
            subsample=trial.suggest_float("xgb_subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("xgb_colsample_bytree", 0.5, 1.0),
            gamma=trial.suggest_float("xgb_gamma", 0.0, 5.0),
            reg_alpha=trial.suggest_float("xgb_reg_alpha", 1e-5, 10.0, log=True),
            reg_lambda=trial.suggest_float("xgb_reg_lambda", 1e-5, 10.0, log=True),
            random_state=42,
            n_jobs=-1
        )

    else:  # DecisionTree
        model = DecisionTreeRegressor(
            max_depth=trial.suggest_int("dt_max_depth", 3, 50),
            min_samples_split=trial.suggest_int("dt_min_samples_split", 2, 10),
            min_samples_leaf=trial.suggest_int("dt_min_samples_leaf", 1, 5),
            max_features=trial.suggest_categorical("dt_max_features", ["sqrt", "log2", None]),
            criterion=trial.suggest_categorical("dt_criterion", ["squared_error", "friedman_mse"]),
            splitter=trial.suggest_categorical("dt_splitter", ["best", "random"]),
            random_state=42
        )

    # --- build pipeline ---
    pipe = Pipeline([
        ('Transformer', transformer),
        ('model', model)
    ])

    # --- cross-validation ---
    cv = KFold(n_splits=3, shuffle=True, random_state=42)
    score = cross_val_score(pipe, xtrain, ytrain, cv=cv, scoring='r2', n_jobs=-1).mean()

    return score

# %%
study = optuna.create_study(
    study_name='In Search of The Champion',
    direction='maximize',
    storage='sqlite:///../reports/autonexus_optuna.db',
    load_if_exists=True
)

study.optimize(objective,n_trials=100)
# Out:
# [I 2025-10-31 19:33:19,533] A new study created in RDB with name: In Search of The Champion
# [I 2025-10-31 19:33:33,470] Trial 0 finished with value: 0.8823638235740129 and parameters: {'encoder_type': 'Freq', 'model': 'XGBoost', 'xgb_n_estimators': 550, 'xgb_learning_rate': 0.07110984732756406, 'xgb_max_depth': 3, 'xgb_min_child_weight': 4.4158717242792145, 'xgb_subsample': 0.6144921878273514, 'xgb_colsample_bytree': 0.5531618154276072, 'xgb_gamma': 2.7122352385815898, 'xgb_reg_alpha': 0.0005245638390492034, 'xgb_reg_lambda': 1.2377152232690528e-05}. Best is trial 0 with value: 0.8823638235740129.
# [I 2025-10-31 19:34:38,032] Trial 1 finished with value: 0.8807216034731314 and parameters: {'encoder_type': 'Freq', 'model': 'RandomForest', 'rf_n_estimators': 500, 'rf_max_depth': 10, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 0 with value: 0.8823638235740129.
# [I 2025-10-31 19:34:59,478] Trial 2 finished with value: 0.6957383723646714 and parameters: {'encoder_type': 'Freq', 'model': 'XGBoost', 'xgb_n_estimators': 150, 'xgb_learning_rate': 0.005148063254811295, 'xgb_max_depth': 12, 'xgb_min_child_weight': 7.767053539380466, 'xgb_subsample': 0.9807170190190411, 'xgb_colsample_bytree': 0.684464236395812, 'xgb_gamma': 1.2877183007959907, 'xgb_reg_alpha': 0.00011242587705871119, 'xgb_reg_lambda': 0.00792184289207849}. Best is trial 0 with value: 0.8823638235740129.
# [I 2025-10-31 19:35:31,085] Trial 3 finished with value: 0.7403560356132991 and parameters: {'encoder_type': 'Freq', 'model': 'RandomForest', 'rf_n_estimators': 600, 'rf_max_depth': 6, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 3, 'rf_max_features': 'log2', 'rf_bootstrap': True}. Best is trial 0 with value: 0.8823638235740129.
# [I 2025-10-31 19:35:43,187] Trial 4 finished with value: 0.8457068704598503 and parameters: {'encoder_type': 'Freq', 'model': 'XGBoost', 'xgb_n_estimators': 200, 'xgb_learning_rate': 0.007690108548973481, 'xgb_max_depth': 9, 'xgb_min_child_weight': 8.849638902841956, 'xgb_subsample': 0.6062342404694353, 'xgb_colsample_bytree': 0.7507370685310266, 'xgb_gamma': 3.9078486796557232, 'xgb_reg_alpha': 0.00027235336260460295, 'xgb_reg_lambda': 0.0006517627571740336}. Best is trial 0 with value: 0.8823638235740129.
# [I 2025-10-31 19:38:54,324] Trial 5 finished with value: 0.919185932815171 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 750, 'rf_max_depth': 17, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 5 with value: 0.919185932815171.
# [I 2025-10-31 19:41:20,094] Trial 6 finished with value: 0.9116019398494984 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 750, 'rf_max_depth': 22, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2', 'rf_bootstrap': True}. Best is trial 5 with value: 0.919185932815171.
# [I 2025-10-31 19:41:45,017] Trial 7 finished with value: 0.591051900300457 and parameters: {'encoder_type': 'Freq', 'model': 'XGBoost', 'xgb_n_estimators': 100, 'xgb_learning_rate': 0.005320086091705443, 'xgb_max_depth': 13, 'xgb_min_child_weight': 1.9452941772005612, 'xgb_subsample': 0.9952293007022787, 'xgb_colsample_bytree': 0.6931074051451559, 'xgb_gamma': 1.5865136202596046, 'xgb_reg_alpha': 0.00019615874632610553, 'xgb_reg_lambda': 2.3269247102645325e-05}. Best is trial 5 with value: 0.919185932815171.
# [I 2025-10-31 19:45:52,545] Trial 8 finished with value: 0.9092464471594185 and parameters: {'encoder_type': 'Count', 'model': 'RandomForest', 'rf_n_estimators': 350, 'rf_max_depth': 44, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_bootstrap': True}. Best is trial 5 with value: 0.919185932815171.
# [I 2025-10-31 19:46:21,159] Trial 9 finished with value: 0.8969335453551119 and parameters: {'encoder_type': 'Count', 'model': 'RandomForest', 'rf_n_estimators': 200, 'rf_max_depth': 15, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 3, 'rf_max_features': 'log2', 'rf_bootstrap': True}. Best is trial 5 with value: 0.919185932815171.
# [I 2025-10-31 19:46:24,214] Trial 10 finished with value: 0.8221156426780493 and parameters: {'encoder_type': 'Target', 'model': 'DecisionTree', 'dt_max_depth': 36, 'dt_min_samples_split': 4, 'dt_min_samples_leaf': 2, 'dt_max_features': 'log2', 'dt_criterion': 'friedman_mse', 'dt_splitter': 'best'}. Best is trial 5 with value: 0.919185932815171.
# [I 2025-10-31 19:50:57,749] Trial 11 finished with value: 0.9212115181935453 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 800, 'rf_max_depth': 26, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 11 with value: 0.9212115181935453.
# [I 2025-10-31 19:51:02,394] Trial 12 finished with value: 0.467661047781842 and parameters: {'encoder_type': 'Target', 'model': 'DecisionTree', 'dt_max_depth': 5, 'dt_min_samples_split': 10, 'dt_min_samples_leaf': 5, 'dt_max_features': 'sqrt', 'dt_criterion': 'squared_error', 'dt_splitter': 'random'}. Best is trial 11 with value: 0.9212115181935453.
# [I 2025-10-31 19:55:39,718] Trial 13 finished with value: 0.9196367348556439 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 800, 'rf_max_depth': 32, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 11 with value: 0.9212115181935453.
# [I 2025-10-31 20:00:12,061] Trial 14 finished with value: 0.9206668808623499 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 800, 'rf_max_depth': 36, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 11 with value: 0.9212115181935453.
# [I 2025-10-31 20:03:45,362] Trial 15 finished with value: 0.9205099420446602 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 600, 'rf_max_depth': 32, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 11 with value: 0.9212115181935453.
# [I 2025-10-31 20:03:53,243] Trial 16 finished with value: 0.8619911133408484 and parameters: {'encoder_type': 'Target', 'model': 'DecisionTree', 'dt_max_depth': 50, 'dt_min_samples_split': 2, 'dt_min_samples_leaf': 1, 'dt_max_features': None, 'dt_criterion': 'squared_error', 'dt_splitter': 'best'}. Best is trial 11 with value: 0.9212115181935453.
# [I 2025-10-31 20:07:40,860] Trial 17 finished with value: 0.9215704999304678 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 650, 'rf_max_depth': 42, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 17 with value: 0.9215704999304678.
# [I 2025-10-31 20:17:59,033] Trial 18 finished with value: 0.8678132588262967 and parameters: {'encoder_type': 'Count', 'model': 'RandomForest', 'rf_n_estimators': 600, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_bootstrap': False}. Best is trial 17 with value: 0.9215704999304678.
# [I 2025-10-31 20:18:05,121] Trial 19 finished with value: 0.7948231826735812 and parameters: {'encoder_type': 'Target', 'model': 'DecisionTree', 'dt_max_depth': 6, 'dt_min_samples_split': 9, 'dt_min_samples_leaf': 5, 'dt_max_features': None, 'dt_criterion': 'friedman_mse', 'dt_splitter': 'random'}. Best is trial 17 with value: 0.9215704999304678.
# [I 2025-10-31 20:22:46,717] Trial 20 finished with value: 0.9239893052115701 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 650, 'rf_max_depth': 41, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 20 with value: 0.9239893052115701.
# [I 2025-10-31 20:26:36,205] Trial 21 finished with value: 0.9226926494231057 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 650, 'rf_max_depth': 41, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 20 with value: 0.9239893052115701.
# [I 2025-10-31 20:31:07,096] Trial 22 finished with value: 0.9233663759383894 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 650, 'rf_max_depth': 43, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 20 with value: 0.9239893052115701.
# [I 2025-10-31 20:33:52,535] Trial 23 finished with value: 0.923487380196477 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 450, 'rf_max_depth': 42, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 20 with value: 0.9239893052115701.
# [I 2025-10-31 20:36:31,951] Trial 24 finished with value: 0.9268134304313502 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 400, 'rf_max_depth': 50, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 20:38:08,794] Trial 25 finished with value: 0.9180318820730756 and parameters: {'encoder_type': 'Count', 'model': 'RandomForest', 'rf_n_estimators': 350, 'rf_max_depth': 50, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 20:49:37,850] Trial 26 finished with value: 0.8813649163195653 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 450, 'rf_max_depth': 47, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_bootstrap': False}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 20:52:21,500] Trial 27 finished with value: 0.9263962304157144 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 400, 'rf_max_depth': 37, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 20:52:50,694] Trial 28 finished with value: 0.9001030367226771 and parameters: {'encoder_type': 'Target', 'model': 'XGBoost', 'xgb_n_estimators': 1000, 'xgb_learning_rate': 0.2644608497793072, 'xgb_max_depth': 3, 'xgb_min_child_weight': 1.6853199447289038, 'xgb_subsample': 0.781425439456497, 'xgb_colsample_bytree': 0.994582804419428, 'xgb_gamma': 0.06970224643209377, 'xgb_reg_alpha': 6.473211008617389, 'xgb_reg_lambda': 7.997437414583382}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 20:52:57,858] Trial 29 finished with value: 0.8154895698666427 and parameters: {'encoder_type': 'Count', 'model': 'DecisionTree', 'dt_max_depth': 23, 'dt_min_samples_split': 7, 'dt_min_samples_leaf': 3, 'dt_max_features': 'log2', 'dt_criterion': 'friedman_mse', 'dt_splitter': 'best'}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 20:53:35,256] Trial 30 finished with value: 0.92006959835345 and parameters: {'encoder_type': 'Target', 'model': 'XGBoost', 'xgb_n_estimators': 950, 'xgb_learning_rate': 0.0285720881264777, 'xgb_max_depth': 7, 'xgb_min_child_weight': 5.665427066600505, 'xgb_subsample': 0.7980689902120025, 'xgb_colsample_bytree': 0.9999873755238358, 'xgb_gamma': 4.5897632291117745, 'xgb_reg_alpha': 0.4916776023690354, 'xgb_reg_lambda': 3.282715775130324}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 20:56:13,046] Trial 31 finished with value: 0.9261741931574178 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 400, 'rf_max_depth': 37, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 20:58:01,055] Trial 32 finished with value: 0.9256421230900015 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 300, 'rf_max_depth': 36, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 20:59:47,207] Trial 33 finished with value: 0.9263840706686971 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 300, 'rf_max_depth': 36, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 21:00:57,729] Trial 34 finished with value: 0.9216761868529076 and parameters: {'encoder_type': 'Freq', 'model': 'RandomForest', 'rf_n_estimators': 250, 'rf_max_depth': 36, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 21:03:26,938] Trial 35 finished with value: 0.9259871306571291 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 400, 'rf_max_depth': 33, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 21:04:46,620] Trial 36 finished with value: 0.9182213222309478 and parameters: {'encoder_type': 'Freq', 'model': 'RandomForest', 'rf_n_estimators': 300, 'rf_max_depth': 27, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 21:06:10,324] Trial 37 finished with value: 0.8875010133267351 and parameters: {'encoder_type': 'Target', 'model': 'XGBoost', 'xgb_n_estimators': 550, 'xgb_learning_rate': 0.264040431360836, 'xgb_max_depth': 15, 'xgb_min_child_weight': 5.5600977933098426, 'xgb_subsample': 0.5007583787694867, 'xgb_colsample_bytree': 0.8544133596364749, 'xgb_gamma': 3.1170937041389846, 'xgb_reg_alpha': 0.03935192362573727, 'xgb_reg_lambda': 0.15132350616001977}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 21:09:31,979] Trial 38 finished with value: 0.9248068722424012 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 500, 'rf_max_depth': 39, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_bootstrap': False}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 21:10:47,023] Trial 39 finished with value: 0.9107058465212327 and parameters: {'encoder_type': 'Freq', 'model': 'RandomForest', 'rf_n_estimators': 100, 'rf_max_depth': 30, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_bootstrap': True}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 21:11:17,277] Trial 40 finished with value: 0.9233333030999636 and parameters: {'encoder_type': 'Target', 'model': 'XGBoost', 'xgb_n_estimators': 700, 'xgb_learning_rate': 0.027895068201156895, 'xgb_max_depth': 8, 'xgb_min_child_weight': 3.627114508275274, 'xgb_subsample': 0.877059988120697, 'xgb_colsample_bytree': 0.5070078168329228, 'xgb_gamma': 4.962635473904408, 'xgb_reg_alpha': 0.007801456593088611, 'xgb_reg_lambda': 0.0010113703931651397}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 21:13:44,857] Trial 41 finished with value: 0.9253689895843934 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 400, 'rf_max_depth': 34, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 21:16:11,388] Trial 42 finished with value: 0.9251501007986526 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 400, 'rf_max_depth': 29, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 21:18:36,477] Trial 43 finished with value: 0.9258961232433348 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 400, 'rf_max_depth': 38, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 21:21:37,369] Trial 44 finished with value: 0.9250706134890678 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 500, 'rf_max_depth': 24, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 24 with value: 0.9268134304313502.
# [I 2025-10-31 21:24:06,959] Trial 45 finished with value: 0.928674879503388 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 350, 'rf_max_depth': 46, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 21:25:12,464] Trial 46 finished with value: 0.923028885283616 and parameters: {'encoder_type': 'Count', 'model': 'RandomForest', 'rf_n_estimators': 200, 'rf_max_depth': 47, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 21:26:51,087] Trial 47 finished with value: 0.9231204570217871 and parameters: {'encoder_type': 'Freq', 'model': 'RandomForest', 'rf_n_estimators': 300, 'rf_max_depth': 46, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 21:26:54,744] Trial 48 finished with value: 0.7844324306490261 and parameters: {'encoder_type': 'Target', 'model': 'DecisionTree', 'dt_max_depth': 24, 'dt_min_samples_split': 6, 'dt_min_samples_leaf': 3, 'dt_max_features': 'sqrt', 'dt_criterion': 'squared_error', 'dt_splitter': 'random'}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 21:28:04,528] Trial 49 finished with value: 0.9187212186716769 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 350, 'rf_max_depth': 45, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_bootstrap': True}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 21:30:43,185] Trial 50 finished with value: 0.9256764027039658 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 450, 'rf_max_depth': 39, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 21:33:15,971] Trial 51 finished with value: 0.9257740096587058 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 400, 'rf_max_depth': 34, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 21:34:18,836] Trial 52 finished with value: 0.8590644467048717 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 500, 'rf_max_depth': 6, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 21:35:44,782] Trial 53 finished with value: 0.9174028781267317 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 350, 'rf_max_depth': 48, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': True}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 21:37:06,681] Trial 54 finished with value: 0.9243403283861608 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 250, 'rf_max_depth': 33, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 2, 'rf_max_features': 'log2', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 21:39:53,191] Trial 55 finished with value: 0.927562160897125 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 450, 'rf_max_depth': 37, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 21:41:55,544] Trial 56 finished with value: 0.9273198208698701 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 300, 'rf_max_depth': 45, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 21:46:13,588] Trial 57 finished with value: 0.9081800652404404 and parameters: {'encoder_type': 'Count', 'model': 'RandomForest', 'rf_n_estimators': 250, 'rf_max_depth': 44, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_bootstrap': True}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 21:46:17,882] Trial 58 finished with value: 0.8054901177964401 and parameters: {'encoder_type': 'Target', 'model': 'DecisionTree', 'dt_max_depth': 50, 'dt_min_samples_split': 2, 'dt_min_samples_leaf': 1, 'dt_max_features': 'log2', 'dt_criterion': 'friedman_mse', 'dt_splitter': 'best'}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 21:50:31,521] Trial 59 finished with value: 0.927666249005426 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 550, 'rf_max_depth': 49, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 21:50:51,239] Trial 60 finished with value: 0.9124373575515676 and parameters: {'encoder_type': 'Target', 'model': 'XGBoost', 'xgb_n_estimators': 350, 'xgb_learning_rate': 0.08873048415164983, 'xgb_max_depth': 5, 'xgb_min_child_weight': 7.123860475643306, 'xgb_subsample': 0.6674416133293085, 'xgb_colsample_bytree': 0.8749064647199856, 'xgb_gamma': 0.002178923876385408, 'xgb_reg_alpha': 1.1877436057090337e-05, 'xgb_reg_lambda': 0.23904907089521865}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 21:54:57,523] Trial 61 finished with value: 0.9272340711942263 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 550, 'rf_max_depth': 50, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 21:58:52,532] Trial 62 finished with value: 0.9270934794932115 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 550, 'rf_max_depth': 49, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 22:03:01,488] Trial 63 finished with value: 0.9280079815568194 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 550, 'rf_max_depth': 50, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 22:06:57,100] Trial 64 finished with value: 0.9277319067085675 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 550, 'rf_max_depth': 48, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 22:11:15,314] Trial 65 finished with value: 0.9270814476287654 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 550, 'rf_max_depth': 45, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 22:15:39,946] Trial 66 finished with value: 0.9273465986874653 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 550, 'rf_max_depth': 48, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 22:20:53,140] Trial 67 finished with value: 0.9280677174258444 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 600, 'rf_max_depth': 48, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 22:20:57,996] Trial 68 finished with value: 0.8679670138803414 and parameters: {'encoder_type': 'Freq', 'model': 'DecisionTree', 'dt_max_depth': 35, 'dt_min_samples_split': 7, 'dt_min_samples_leaf': 4, 'dt_max_features': None, 'dt_criterion': 'squared_error', 'dt_splitter': 'random'}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 22:25:26,162] Trial 69 finished with value: 0.9209202935639077 and parameters: {'encoder_type': 'Count', 'model': 'RandomForest', 'rf_n_estimators': 700, 'rf_max_depth': 48, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 22:29:02,893] Trial 70 finished with value: 0.9194675504602783 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 600, 'rf_max_depth': 47, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 22:34:00,050] Trial 71 finished with value: 0.9267682093234751 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 600, 'rf_max_depth': 44, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 22:37:55,094] Trial 72 finished with value: 0.9279966453705256 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 550, 'rf_max_depth': 46, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 22:42:07,256] Trial 73 finished with value: 0.9271731068226102 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 550, 'rf_max_depth': 48, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 22:46:32,545] Trial 74 finished with value: 0.926752420760946 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 600, 'rf_max_depth': 42, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 45 with value: 0.928674879503388.
# [I 2025-10-31 22:52:36,078] Trial 75 finished with value: 0.928902779667283 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 550, 'rf_max_depth': 50, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 75 with value: 0.928902779667283.
# [I 2025-10-31 23:09:07,759] Trial 76 finished with value: 0.8754279297359036 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 500, 'rf_max_depth': 50, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_bootstrap': False}. Best is trial 75 with value: 0.928902779667283.
# [I 2025-10-31 23:10:23,111] Trial 77 finished with value: 0.9256603763929357 and parameters: {'encoder_type': 'Target', 'model': 'XGBoost', 'xgb_n_estimators': 750, 'xgb_learning_rate': 0.012986714928648113, 'xgb_max_depth': 11, 'xgb_min_child_weight': 3.3129341097785256, 'xgb_subsample': 0.8836383868658204, 'xgb_colsample_bytree': 0.5936117855180681, 'xgb_gamma': 1.6332185510594686, 'xgb_reg_alpha': 5.4909128476895095, 'xgb_reg_lambda': 0.00026887760118958276}. Best is trial 75 with value: 0.928902779667283.
# [I 2025-10-31 23:14:37,680] Trial 78 finished with value: 0.9284965536929248 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 700, 'rf_max_depth': 19, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 75 with value: 0.928902779667283.
# [I 2025-10-31 23:18:21,261] Trial 79 finished with value: 0.9286509316089383 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 700, 'rf_max_depth': 18, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 75 with value: 0.928902779667283.
# [I 2025-10-31 23:21:25,740] Trial 80 finished with value: 0.9241799231193801 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 750, 'rf_max_depth': 18, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': True}. Best is trial 75 with value: 0.928902779667283.
# [I 2025-10-31 23:24:52,852] Trial 81 finished with value: 0.9254660330527135 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 700, 'rf_max_depth': 17, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 75 with value: 0.928902779667283.
# [I 2025-10-31 23:27:15,698] Trial 82 finished with value: 0.9202941483668594 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 700, 'rf_max_depth': 12, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 75 with value: 0.928902779667283.
# [I 2025-10-31 23:32:13,179] Trial 83 finished with value: 0.92801831468031 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 750, 'rf_max_depth': 20, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 75 with value: 0.928902779667283.
# [I 2025-10-31 23:37:27,140] Trial 84 finished with value: 0.9281808461464519 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 800, 'rf_max_depth': 19, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 75 with value: 0.928902779667283.
# [I 2025-10-31 23:43:50,600] Trial 85 finished with value: 0.9269806368597687 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 800, 'rf_max_depth': 21, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 75 with value: 0.928902779667283.
# [I 2025-10-31 23:48:23,694] Trial 86 finished with value: 0.9237001453682808 and parameters: {'encoder_type': 'Freq', 'model': 'RandomForest', 'rf_n_estimators': 750, 'rf_max_depth': 20, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 75 with value: 0.928902779667283.
# [I 2025-10-31 23:51:30,301] Trial 87 finished with value: 0.9236945854429889 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 750, 'rf_max_depth': 14, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 75 with value: 0.928902779667283.
# [I 2025-10-31 23:51:34,750] Trial 88 finished with value: 0.76902448715598 and parameters: {'encoder_type': 'Target', 'model': 'DecisionTree', 'dt_max_depth': 15, 'dt_min_samples_split': 4, 'dt_min_samples_leaf': 2, 'dt_max_features': 'sqrt', 'dt_criterion': 'squared_error', 'dt_splitter': 'random'}. Best is trial 75 with value: 0.928902779667283.
# [I 2025-10-31 23:54:19,138] Trial 89 finished with value: 0.920200037462401 and parameters: {'encoder_type': 'Count', 'model': 'RandomForest', 'rf_n_estimators': 650, 'rf_max_depth': 17, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 75 with value: 0.928902779667283.
# [I 2025-11-01 00:23:18,415] Trial 90 finished with value: 0.8939277416269893 and parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 800, 'rf_max_depth': 19, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_bootstrap': False}. Best is trial 75 with value: 0.928902779667283.
# [W 2025-11-01 00:27:55,702] Trial 91 failed with parameters: {'encoder_type': 'Target', 'model': 'RandomForest', 'rf_n_estimators': 700, 'rf_max_depth': 24, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False} because of the following error: ValueError('\nAll the 3 fits failed.\nIt is very likely that your model is misconfigured.\nYou can try to debug the error by setting error_score=\'raise\'.\n\nBelow are more details about the failures:\n--------------------------------------------------------------------------------\n3 fits failed with the following error:\njoblib.externals.loky.process_executor._RemoteTraceback: \n"""\nTraceback (most recent call last):\n  File "c:\\Users\\aksha\\OneDrive\\Desktop\\AutoNexusMlOps\\ANenv\\Lib\\site-packages\\joblib\\_utils.py", line 72, in __call__\n    return self.func(**kwargs)\n           ^^^^^^^^^^^^^^^^^^^\n  File "c:\\Users\\aksha\\OneDrive\\Desktop\\AutoNexusMlOps\\ANenv\\Lib\\site-packages\\joblib\\parallel.py", line 607, in __call__\n    return [func(*args, **kwargs) for func, args, kwargs in self.items]\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "c:\\Users\\aksha\\OneDrive\\Desktop\\AutoNexusMlOps\\ANenv\\Lib\\site-packages\\joblib\\parallel.py", line 607, in <listcomp>\n    return [func(*args, **kwargs) for func, args, kwargs in self.items]\n            ^^^^^^^^^^^^^^^^^^^^^\n  File "c:\\Users\\aksha\\OneDrive\\Desktop\\AutoNexusMlOps\\ANenv\\Lib\\site-packages\\sklearn\\utils\\parallel.py", line 147, in __call__\n    return self.function(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "c:\\Users\\aksha\\OneDrive\\Desktop\\AutoNexusMlOps\\ANenv\\Lib\\site-packages\\sklearn\\ensemble\\_forest.py", line 196, in _parallel_build_trees\n    tree._fit(\n  File "c:\\Users\\aksha\\OneDrive\\Desktop\\AutoNexusMlOps\\ANenv\\Lib\\site-packages\\sklearn\\tree\\_classes.py", line 472, in _fit\n    builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)\n  File "sklearn/tree/_tree.pyx", line 141, in sklearn.tree._tree.DepthFirstTreeBuilder.build\n  File "sklearn/tree/_tree.pyx", line 256, in sklearn.tree._tree.DepthFirstTreeBuilder.build\n  File "sklearn/tree/_tree.pyx", line 911, in sklearn.tree._tree.Tree._add_node\n  File "sklearn/tree/_tree.pyx", line 879, in sklearn.tree._tree.Tree._resize_c\n  File "sklearn/tree/_utils.pyx", line 29, in sklearn.tree._utils.safe_realloc\nMemoryError: could not allocate 8388608 bytes\n"""\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File "c:\\Users\\aksha\\OneDrive\\Desktop\\AutoNexusMlOps\\ANenv\\Lib\\site-packages\\sklearn\\model_selection\\_validation.py", line 859, in _fit_and_score\n    estimator.fit(X_train, y_train, **fit_params)\n  File "c:\\Users\\aksha\\OneDrive\\Desktop\\AutoNexusMlOps\\ANenv\\Lib\\site-packages\\sklearn\\base.py", line 1365, in wrapper\n    return fit_method(estimator, *args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "c:\\Users\\aksha\\OneDrive\\Desktop\\AutoNexusMlOps\\ANenv\\Lib\\site-packages\\sklearn\\pipeline.py", line 663, in fit\n    self._final_estimator.fit(Xt, y, **last_step_params["fit"])\n  File "c:\\Users\\aksha\\OneDrive\\Desktop\\AutoNexusMlOps\\ANenv\\Lib\\site-packages\\sklearn\\base.py", line 1365, in wrapper\n    return fit_method(estimator, *args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "c:\\Users\\aksha\\OneDrive\\Desktop\\AutoNexusMlOps\\ANenv\\Lib\\site-packages\\sklearn\\ensemble\\_forest.py", line 486, in fit\n    trees = Parallel(\n            ^^^^^^^^^\n  File "c:\\Users\\aksha\\OneDrive\\Desktop\\AutoNexusMlOps\\ANenv\\Lib\\site-packages\\sklearn\\utils\\parallel.py", line 82, in __call__\n    return super().__call__(iterable_with_config_and_warning_filters)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "c:\\Users\\a ...
# Traceback (most recent call last):
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\optuna\study\_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\aksha\AppData\Local\Temp\ipykernel_12676\1004410926.py", line 96, in objective
#     score = cross_val_score(pipe, xtrain, ytrain, cv=cv, scoring='r2', n_jobs=-1).mean()
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\utils\_param_validation.py", line 218, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\model_selection\_validation.py", line 677, in cross_val_score
#     cv_results = cross_validate(
#                  ^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\utils\_param_validation.py", line 218, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\model_selection\_validation.py", line 419, in cross_validate
#     _warn_or_raise_about_fit_failures(results, error_score)
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\model_selection\_validation.py", line 505, in _warn_or_raise_about_fit_failures
#     raise ValueError(all_fits_failed_message)
# ValueError:
# All the 3 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\_utils.py", line 72, in __call__
#     return self.func(**kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\parallel.py", line 607, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\utils\parallel.py", line 147, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\ensemble\_forest.py", line 196, in _parallel_build_trees
#     tree._fit(
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\tree\_classes.py", line 472, in _fit
#     builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#   File "sklearn/tree/_tree.pyx", line 141, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn/tree/_tree.pyx", line 256, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn/tree/_tree.pyx", line 911, in sklearn.tree._tree.Tree._add_node
#   File "sklearn/tree/_tree.pyx", line 879, in sklearn.tree._tree.Tree._resize_c
#   File "sklearn/tree/_utils.pyx", line 29, in sklearn.tree._utils.safe_realloc
# MemoryError: could not allocate 8388608 bytes
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\pipeline.py", line 663, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\ensemble\_forest.py", line 486, in fit
#     trees = Parallel(
#             ^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\utils\parallel.py", line 82, in __call__
#     return super().__call__(iterable_with_config_and_warning_filters)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\parallel.py", line 1784, in _retrieve
#     self._raise_error_fast()
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\parallel.py", line 1859, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\parallel.py", line 758, in get_result
#     return self._return_or_raise()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\parallel.py", line 773, in _return_or_raise
#     raise self._result
# MemoryError: could not allocate 8388608 bytes
#
# [W 2025-11-01 00:27:55,780] Trial 91 failed with value None.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 8
#       1 study = optuna.create_study(
#       2     study_name='In Search of The Champion',
#       3     direction='maximize',
#       4     storage='sqlite:///../reports/autonexus_optuna.db',
#       5     load_if_exists=True
#       6 )
# ----> 8 study.optimize(objective,n_trials=100)
#
# File c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\optuna\study\study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\optuna\study\_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\optuna\study\_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial_id = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\optuna\study\_optimize.py:258, in _run_trial(study, func, catch)
#     251         assert False, "Should not reach."
#     253 if (
#     254     updated_state == TrialState.FAIL
#     255     and func_err is not None
#     256     and not isinstance(func_err, catch)
#     257 ):
# --> 258     raise func_err
#     259 return trial._trial_id
#
# File c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\optuna\study\_optimize.py:201, in _run_trial(study, func, catch)
#     199 with get_heartbeat_thread(trial._trial_id, study._storage):
#     200     try:
# --> 201         value_or_values = func(trial)
#     202     except exceptions.TrialPruned as e:
#     203         # TODO(mamu): Handle multi-objective cases.
#     204         state = TrialState.PRUNED
#
# Cell In[14], line 96, in objective(trial)
#      94 # --- cross-validation ---
#      95 cv = KFold(n_splits=3, shuffle=True, random_state=42)
# ---> 96 score = cross_val_score(pipe, xtrain, ytrain, cv=cv, scoring='r2', n_jobs=-1).mean()
#      98 return score
#
# File c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\model_selection\_validation.py:677, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, error_score)
#     674 # To ensure multimetric format is not supported
#     675 scorer = check_scoring(estimator, scoring=scoring)
# --> 677 cv_results = cross_validate(
#     678     estimator=estimator,
#     679     X=X,
#     680     y=y,
#     681     groups=groups,
#     682     scoring={"score": scorer},
#     683     cv=cv,
#     684     n_jobs=n_jobs,
#     685     verbose=verbose,
#     686     params=params,
#     687     pre_dispatch=pre_dispatch,
#     688     error_score=error_score,
#     689 )
#     690 return cv_results["test_score"]
#
# File c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\model_selection\_validation.py:419, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     398 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
#     399 results = parallel(
#     400     delayed(_fit_and_score)(
#     401         clone(estimator),
#    (...)    416     for train, test in indices
#     417 )
# --> 419 _warn_or_raise_about_fit_failures(results, error_score)
#     421 # For callable scoring, the return type is only know after calling. If the
#     422 # return type is a dictionary, the error scores can now be inserted with
#     423 # the correct key.
#     424 if callable(scoring):
#
# File c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\model_selection\_validation.py:505, in _warn_or_raise_about_fit_failures(results, error_score)
#     498 if num_failed_fits == num_fits:
#     499     all_fits_failed_message = (
#     500         f"\nAll the {num_fits} fits failed.\n"
#     501         "It is very likely that your model is misconfigured.\n"
#     502         "You can try to debug the error by setting error_score='raise'.\n\n"
#     503         f"Below are more details about the failures:\n{fit_errors_summary}"
#     504     )
# --> 505     raise ValueError(all_fits_failed_message)
#     507 else:
#     508     some_fits_failed_message = (
#     509         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     510         "The score on these train-test partitions for these parameters"
#    (...)    514         f"Below are more details about the failures:\n{fit_errors_summary}"
#     515     )
#
# ValueError:
# All the 3 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\_utils.py", line 72, in __call__
#     return self.func(**kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\parallel.py", line 607, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\utils\parallel.py", line 147, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\ensemble\_forest.py", line 196, in _parallel_build_trees
#     tree._fit(
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\tree\_classes.py", line 472, in _fit
#     builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#   File "sklearn/tree/_tree.pyx", line 141, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn/tree/_tree.pyx", line 256, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn/tree/_tree.pyx", line 911, in sklearn.tree._tree.Tree._add_node
#   File "sklearn/tree/_tree.pyx", line 879, in sklearn.tree._tree.Tree._resize_c
#   File "sklearn/tree/_utils.pyx", line 29, in sklearn.tree._utils.safe_realloc
# MemoryError: could not allocate 8388608 bytes
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\pipeline.py", line 663, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\ensemble\_forest.py", line 486, in fit
#     trees = Parallel(
#             ^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\sklearn\utils\parallel.py", line 82, in __call__
#     return super().__call__(iterable_with_config_and_warning_filters)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\parallel.py", line 1784, in _retrieve
#     self._raise_error_fast()
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\parallel.py", line 1859, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\parallel.py", line 758, in get_result
#     return self._return_or_raise()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\aksha\OneDrive\Desktop\AutoNexusMlOps\ANenv\Lib\site-packages\joblib\parallel.py", line 773, in _return_or_raise
#     raise self._result
# MemoryError: could not allocate 8388608 bytes

# %%
# tracking the records

mlflow.set_tracking_uri('https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow')
dagshub.init(repo_owner='akshatsharma2407', repo_name='AutoNexusMlOps', mlflow=True)
# Out:
# Accessing as akshatsharma2407
# Initialized MLflow to track repo "akshatsharma2407/AutoNexusMlOps"
# Repository akshatsharma2407/AutoNexusMlOps initialized!

# %%
mlflow.set_experiment(experiment_name='In Search of Champion')
for trial in study.trials:
    with mlflow.start_run(run_name=f"trial_{trial.number}"):
        mlflow.log_params(trial.params)
        
        if trial.value:
            mlflow.log_metric("objective", trial.value)
        
        mlflow.set_tag("state", trial.state.name)
        mlflow.set_tag("trial_number", trial.number)
# Out:
# 2025/11/01 00:28:58 INFO mlflow.tracking.fluent: Experiment with name 'In Search of Champion' does not exist. Creating a new experiment.
# 🏃 View run trial_0 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/7cf18f74389340d198f9f1bc34049b4e
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_1 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/1199a876e310494186856faa569a84b9
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_2 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/871e41388df7407ab07fc249350676db
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_3 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/2ff787b520ab45729014025fee963e52
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_4 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/443703b5bdfd490987edcd2907f0945e
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_5 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/84b654b81c444d368637d942b4e267f3
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_6 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/12f1726e243640eeb3d989522ac0bfdd
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_7 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/c3192840abc5425d86a2384fc8de7ca3
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_8 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/71632216ff1544ae95c8e1a2b6c7b6e2
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_9 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/6b7c7fe715e1448b89daf282cce8e6d5
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_10 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/7ec24f4757804f72842f89b00a4596db
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_11 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/ae40f29e6f884ea4b13a74a5da836104
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_12 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/e9c9f53227d74bd3bcf3390fa34d7791
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_13 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/d909926fe9c847d19960ca3950c8efc3
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_14 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/3a56553b758a4f53b137fd0a93cbc15e
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_15 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/4b738e06f0014a16bb28355b7775d7f0
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_16 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/433c1ca7ce134a2bbf93bf6d1e49f75d
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_17 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/4538b6d3c8d046a0b1804b5e6459fefb
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_18 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/306c2751b77c49a5b35b43e6b2ce81d2
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_19 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/96815a97deee498f9c919c373dfaf5ff
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_20 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/7ee10a101db34520a1d7fa39dd74c511
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_21 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/70629ad1264e412f8b709f73e12a3a60
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_22 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/88e8c1bc1f8c4bc086e535b51c67543d
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_23 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/9e0293386eb74cc88b3f8b1977f9982c
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_24 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/b454ce5f87494a85a64f3c7e072bccff
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_25 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/bfb023caab8741979e3fa1dea9cef92f
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_26 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/4d300d589beb4858893b1bc5bc8e5fc1
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_27 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/6dbb04bc19d1477a8e0a897f18743e4a
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_28 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/a91933681b864109b2d994a2a2e4c3c5
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_29 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/53ef2ec7616346e4bdc6fe936200dd87
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_30 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/055e7249235d4d1688bee85684af13f8
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_31 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/be56045c1f2e4d0dbc95d8f7bc747ddb
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_32 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/8cd80decd8744eefaa5fd17c768a0444
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_33 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/e98ffffed3fd4accad8ba9e3b1c27c9e
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_34 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/ebf2e1be2fc54690a8f9de2e7ade3bc3
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_35 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/8f2d18d0e4654b0d9e2243969e133770
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_36 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/68274c7f54884fb791d34787f0637744
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_37 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/230ea1b9dadf4188804384a6fa2f467c
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_38 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/f3fda8a9b8e343c8a568c388bef9517c
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_39 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/911968b05e334f1895afbde4d0ce0b6e
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_40 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/9ba87758cf4f424d8226c0cadd15731b
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_41 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/30cf2021bce746a5a301cfdcdd573df9
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_42 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/04f78da9cf8e4a09892dde5f0cce462c
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_43 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/03d01eb7889b4acf8b1bace3b2a1205c
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_44 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/817aefa1875648cab39044962b815af5
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_45 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/32ab0d9b095d4e5dba6ce0cf92618530
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_46 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/a2c89935080b4cb3856dcc116ff57519
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_47 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/94f5605818d244ddb6ef040678d246fc
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_48 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/677c93abdd334241b8294f1abee9156b
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_49 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/8392dd4f128849dfb9ddfdec6cf05a4a
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_50 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/f13489e7847b4a0887fb471b695b4878
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_51 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/90be3ac3526448d69b0fd99b0331c792
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_52 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/ef36a3c2c19647cfba8cb05fac340b06
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_53 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/77754de5e439401592d424eabd64508d
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_54 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/5a641a3eff94424b9b86638cae0cf0b4
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_55 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/9c9c5c4a8630480bb52fdebfc3012163
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_56 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/a686920561044b598573273a50ba1385
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_57 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/35ccf048e9f04d219dfdb3261bb4bd7c
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_58 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/e16ef55df052403c8279ed6d3ade1661
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_59 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/85c7f9c43650495690a434fca707f732
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_60 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/058c378fa67043d69dd9327cf81de311
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_61 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/f5d1a96ac6e14938b89372a7f67826d7
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_62 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/36beadfa22914c8c938712302c5e00d0
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_63 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/1fd590b408b24dac81bdbc8a5b479ae6
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_64 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/392a0555a7144817bbc9c7b9575e87b3
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_65 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/e4ed387bbc5549c4a8fe0bf50b730e08
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_66 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/a9862ae2cb304b5b87d135517f502d39
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_67 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/fd334ecf8c2d4457afe13d652db9458d
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_68 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/438d25735c92401ea7b8333552c7ef26
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_69 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/6749e26ed8a241d3b337533ac2be72fc
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_70 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/9888b66d51f24697b8ae134570458eda
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_71 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/54bf885a046f458dbb9fbccadddb9907
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_72 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/e6ca75399d0d428793c6c379f6a82de6
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_73 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/c0ecb00133f94e0bb688307d11e77c78
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_74 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/7c6d3322807644598eea2c1b737f8f90
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_75 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/389271f28d174d44b70d2f9004017cdd
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_76 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/e9402c003fe1473cb0a99525e67bf38e
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_77 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/3ced10fdeaff415087363d8efa3ce5ee
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_78 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/c59240ec3d044b77af3518e755988929
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_79 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/28fce9b1b0ea4e418353d0774d3fdcd5
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_80 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/aee1c28237814a69b6a1cec826fc85b3
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_81 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/e3e43112d54842d7a94f3996a489a82b
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_82 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/e65149fe1f5543c1823ddecd9b4fae6b
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_83 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/d73ac67027384258a4c58600b57c537b
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_84 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/a1294becdd784e5f9bb3609b94846dde
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_85 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/8b644c4890bb4f0a93eae8af745d1239
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_86 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/e2b7a2f4d5b243acb16ce999140c76ed
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_87 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/6438158aba124760b9cf9495e4c25b90
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_88 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/dae137c8a7524c0f8bdd2b3c50fc5846
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_89 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/bb1ae366719e4833aa136a474d22a443
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_90 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/4fdfe6e675e04aadbdb9218998addd25
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
# 🏃 View run trial_91 at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5/runs/0e602a555de648c081a9723521ce8bb4
# 🧪 View experiment at: https://dagshub.com/akshatsharma2407/AutoNexusMlOps.mlflow/#/experiments/5
